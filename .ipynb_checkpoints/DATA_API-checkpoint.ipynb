# %% [markdown]
# # Extrayendo datos desde las api públicas de mercado libre

# %% [markdown]
# Con el metodo get de la librería requests se consumiran las apis. La primera api a consumir, será el diccionario de categorías existentes a la fecha en mercado libre.

# %%
import requests 
from tqdm import tqdm
import pandas as pd

# %%
r =requests.get('https://api.mercadolibre.com/sites/MCO/categories') #api de las categorias consultada en https://developers.mercadolibre.com.ar/es_ar/categoriza-productos

# %% [markdown]
# Se guardan los resultados como un .json y se recorre este diccionario pintando las diferentes categorías:

# %%
diccat = r.json()
for cat in diccat:
    print(cat)
# Out:
# {'id': 'MCO1747', 'name': 'Accesorios para Vehículos'}
# {'id': 'MCO441917', 'name': 'Agro'}
# {'id': 'MCO1403', 'name': 'Alimentos y Bebidas'}
# {'id': 'MCO1071', 'name': 'Animales y Mascotas'}
# {'id': 'MCO1367', 'name': 'Antigüedades y Colecciones'}
# {'id': 'MCO1368', 'name': 'Arte, Papelería y Mercería'}
# {'id': 'MCO1384', 'name': 'Bebés'}
# {'id': 'MCO1246', 'name': 'Belleza y Cuidado Personal'}
# {'id': 'MCO40433', 'name': 'Boletas para Espectáculos'}
# {'id': 'MCO1039', 'name': 'Cámaras y Accesorios'}
# {'id': 'MCO1743', 'name': 'Carros, Motos y Otros'}
# {'id': 'MCO1051', 'name': 'Celulares y Teléfonos'}
# {'id': 'MCO1648', 'name': 'Computación'}
# {'id': 'MCO1144', 'name': 'Consolas y Videojuegos'}
# {'id': 'MCO172890', 'name': 'Construcción'}
# {'id': 'MCO1276', 'name': 'Deportes y Fitness'}
# {'id': 'MCO5726', 'name': 'Electrodomésticos'}
# {'id': 'MCO1000', 'name': 'Electrónica, Audio y Video'}
# {'id': 'MCO175794', 'name': 'Herramientas'}
# {'id': 'MCO1574', 'name': 'Hogar y Muebles'}
# {'id': 'MCO1499', 'name': 'Industrias y Oficinas'}
# {'id': 'MCO1459', 'name': 'Inmuebles'}
# {'id': 'MCO1182', 'name': 'Instrumentos Musicales'}
# {'id': 'MCO1132', 'name': 'Juegos y Juguetes'}
# {'id': 'MCO3025', 'name': 'Libros, Revistas y Comics'}
# {'id': 'MCO1168', 'name': 'Música, Películas y Series'}
# {'id': 'MCO118204', 'name': 'Recuerdos, Piñatería y Fiestas'}
# {'id': 'MCO3937', 'name': 'Relojes y Joyas'}
# {'id': 'MCO1430', 'name': 'Ropa y Accesorios'}
# {'id': 'MCO180800', 'name': 'Salud y Equipamiento Médico'}
# {'id': 'MCO1540', 'name': 'Servicios'}
# {'id': 'MCO1953', 'name': 'Otras categorías'}

# %% [markdown]
# La api que contiene las características de cada categoría es: "https://api.mercadolibre.com/sites/MCO/search?category=id_cat&offset=numerodehoja", donde id_cat es el id de la categoría de interés y numerodehoja es el número de offset a consultar, un ejemplo es:

# %%
e =requests.get('https://api.mercadolibre.com/sites/MCO/search?category=MCO1071&offset=2')
e.json()
# Out:
# {'site_id': 'MCO',
#  'paging': {'total': 773084,
#   'primary_results': 1000,
#   'offset': 2,
#   'limit': 50},
#  'results': [{'id': 'MCO559825157',
#    'site_id': 'MCO',
#    'title': 'Tapete De Entrenamiento  Para Perro Grande Nuevo',
#    'seller': {'id': 549945381,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 65900,
#    'prices': {'id': 'MCO559825157',
#     'prices': [{'id': '9',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 65900,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-04-22T17:23:54Z'},
#      {'id': '11',
#       'type': 'promotion',
#       'conditions': {'context_restrictions': [],
#        'start_time': '2021-04-28T05:00:00Z',
#        'end_time': '2021-05-01T04:59:59Z',
#        'eligible': True},
#       'amount': 62605,
#       'regular_amount': 65900,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {'promotion_id': '82756-MCO559825157',
#        'promotion_type': 'custom'},
#       'last_updated': '2021-04-28T14:56:16Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 50,
#    'sold_quantity': 500,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-04-19T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-559825157-tapete-de-entrenamiento-para-perro-grande-nuevo-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_742849-MCO41537350314_042020-I.jpg',
#    'thumbnail_id': '742849-MCO41537350314_042020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 5491.67,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-DC',
#     'state_name': 'Bogotá D.C.',
#     'city_id': 'TUNPQ01BUjU5NzU1',
#     'city_name': 'Martires'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'logistic_type': 'cross_docking',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-DC', 'name': 'Bogotá D.C.'},
#     'city': {'id': 'TUNPQ01BUjU5NzU1', 'name': 'Martires'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': None,
#      'source': 6808261514773724,
#      'attribute_group_name': 'Otros',
#      'value_name': 'Potty Patch',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Potty Patch',
#        'struct': None,
#        'source': 6808261514773724}],
#      'attribute_group_id': 'OTHERS'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'source': 6808261514773724},
#     {'value_name': '68 cm',
#      'value_struct': {'number': 68, 'unit': 'cm'},
#      'attribute_group_name': 'Otros',
#      'attribute_group_id': 'OTHERS',
#      'source': 6808261514773724,
#      'id': 'LENGTH',
#      'name': 'Largo',
#      'value_id': None,
#      'values': [{'struct': {'number': 68, 'unit': 'cm'},
#        'source': 6808261514773724,
#        'id': None,
#        'name': '68 cm'}]},
#     {'value_id': None,
#      'values': [{'struct': None,
#        'source': 7092,
#        'id': None,
#        'name': 'Adulto'}],
#      'attribute_group_name': 'Otros',
#      'source': 7092,
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_name': 'Adulto',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'value_name': '1',
#      'attribute_group_name': 'Otros',
#      'source': 6808261514773724,
#      'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': None,
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 6808261514773724}],
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33602181},
#    'original_price': None,
#    'category_id': 'MCO155541',
#    'official_store_id': None,
#    'domain_id': 'MCO-DOG_POTTY_PADS',
#    'catalog_product_id': None,
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate'],
#    'order_backend': 1,
#    'use_thumbnail_id': True},
#   {'id': 'MCO450538980',
#    'site_id': 'MCO',
#    'title': 'Forro Silla Carro Perro Mascota - Unidad a $34900',
#    'seller': {'id': 152737872,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 34900,
#    'prices': {'id': 'MCO450538980',
#     'prices': [{'id': '2',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 34900,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-04-22T22:12:38Z'},
#      {'id': '4',
#       'type': 'promotion',
#       'conditions': {'context_restrictions': [],
#        'start_time': '2021-05-31T05:00:00Z',
#        'end_time': '2021-06-01T04:59:59Z',
#        'eligible': True},
#       'amount': 33155,
#       'regular_amount': 34900,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {'promotion_id': '145421-MCO450538980',
#        'promotion_type': 'deal_of_the_day'},
#       'last_updated': '2021-05-24T15:37:41Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 500,
#    'sold_quantity': 500,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2040-01-31T22:32:14.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-450538980-forro-silla-carro-perro-mascota-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_924849-MCO45644165953_042021-O.jpg',
#    'thumbnail_id': '924849-MCO45644165953_042021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 36,
#     'amount': 969.44,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-DC',
#     'state_name': 'Bogotá D.C.',
#     'city_id': 'TUNPQ0tFTjQyODYy',
#     'city_name': 'Kennedy'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'logistic_type': 'cross_docking',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-DC', 'name': 'Bogotá D.C.'},
#     'city': {'id': 'TUNPQ0tFTjQyODYy', 'name': 'Kennedy'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_id': None,
#      'value_name': 'VELBROS',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'VELBROS',
#        'struct': None,
#        'source': 3376461333454861}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'BRAND',
#      'attribute_group_name': 'Otros',
#      'source': 3376461333454861},
#     {'source': 1,
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem'},
#     {'id': 'UNITS_PER_PACKAGE',
#      'name': 'Unidades por envase',
#      'value_id': None,
#      'value_struct': None,
#      'value_name': '1',
#      'values': [{'id': None,
#        'name': '1',
#        'struct': None,
#        'source': 3376461333454861}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 3376461333454861}],
#    'original_price': None,
#    'category_id': 'MCO74394',
#    'official_store_id': None,
#    'domain_id': 'MCO-ANIMAL_AND_PET_PRODUCTS',
#    'catalog_product_id': None,
#    'tags': ['dragged_bids_and_visits',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate'],
#    'order_backend': 2,
#    'use_thumbnail_id': False},
#   {'id': 'MCO576995168',
#    'site_id': 'MCO',
#    'title': 'Maquina Peluqueria Canina Progemei Profesional / Impoluz',
#    'seller': {'id': 468328073,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 67900,
#    'prices': {'id': 'MCO576995168',
#     'prices': [{'id': '1',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 67900,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-05-07T13:09:11Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 250,
#    'sold_quantity': 250,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2040-08-08T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-576995168-maquina-peluqueria-canina-progemei-profesional-impoluz-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_815201-MCO44222575025_122020-O.jpg',
#    'thumbnail_id': '815201-MCO44222575025_122020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 36,
#     'amount': 1886.11,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-DC',
#     'state_name': 'Bogotá D.C.',
#     'city_id': 'TUNPQ1RFVTY1OTk1',
#     'city_name': 'Teusaquillo'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'logistic_type': 'cross_docking',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-DC', 'name': 'Bogotá D.C.'},
#     'city': {'id': 'TUNPQ1RFVTY1OTk1', 'name': 'Teusaquillo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 6808261514773724,
#      'name': 'Marca',
#      'value_id': None,
#      'value_struct': None,
#      'id': 'BRAND',
#      'value_name': 'ZEBBRIS',
#      'values': [{'struct': None,
#        'source': 6808261514773724,
#        'id': None,
#        'name': 'ZEBBRIS'}]},
#     {'id': 'ITEM_CONDITION',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 6808261514773724,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'value_struct': None},
#     {'value_name': 'Maquina canina inalambrica',
#      'source': 6808261514773724,
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'Maquina canina inalambrica',
#        'struct': None,
#        'source': 6808261514773724}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros'},
#     {'values': [{'source': 3376461333454861,
#        'id': '-1',
#        'name': None,
#        'struct': None}],
#      'attribute_group_name': 'Otros',
#      'source': 3376461333454861,
#      'id': 'POWER',
#      'name': 'Potencia',
#      'value_id': '-1',
#      'value_name': None,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'}],
#    'original_price': None,
#    'category_id': 'MCO155534',
#    'official_store_id': None,
#    'domain_id': 'MCO-ANIMAL_CLIPPERS',
#    'catalog_product_id': None,
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate'],
#    'order_backend': 3,
#    'use_thumbnail_id': False},
#   {'id': 'MCO604986848',
#    'site_id': 'MCO',
#    'title': 'Forro Sillas Funda Protector Mascota Cobertor Carro Perro',
#    'seller': {'id': 540113370,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 44000,
#    'prices': {'id': 'MCO604986848',
#     'prices': [{'id': '2',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 44000,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-05-24T04:33:17Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 150,
#    'sold_quantity': 25,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2041-01-25T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-604986848-forro-sillas-funda-protector-mascota-cobertor-carro-perro-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_831960-MCO44762203595_012021-O.jpg',
#    'thumbnail_id': '831960-MCO44762203595_012021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 36,
#     'amount': 1222.22,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-DC',
#     'state_name': 'Bogotá D.C.',
#     'city_id': 'TUNPQ0tFTjQyODYy',
#     'city_name': 'Kennedy'},
#    'shipping': {'free_shipping': True,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': 'not_specified',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-DC', 'name': 'Bogotá D.C.'},
#     'city': {'id': 'TUNPQ0tFTjQyODYy', 'name': 'Kennedy'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 1505,
#      'values': [{'id': None, 'name': 'Liso', 'struct': None, 'source': 1505}],
#      'attribute_group_name': 'Otros',
#      'id': 'COAT_LENGTH',
#      'name': 'Largo del pelaje',
#      'value_name': 'Liso',
#      'value_struct': None},
#     {'source': 81068639424647,
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 81068639424647}],
#      'attribute_group_name': 'Otros',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_struct': None}],
#    'original_price': None,
#    'category_id': 'MCO1073',
#    'official_store_id': None,
#    'domain_id': 'MCO-PUREBRED_DOGS',
#    'catalog_product_id': None,
#    'tags': ['good_quality_thumbnail',
#     'good_quality_picture',
#     'immediate_payment'],
#    'order_backend': 4,
#    'use_thumbnail_id': False},
#   {'id': 'MCO615351672',
#    'site_id': 'MCO',
#    'title': 'Alimento Comida Gato Gatsy Pescado Arroz Espinaca 3000 Gr',
#    'seller': {'id': 259944770,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 35000,
#    'prices': {'id': 'MCO615351672',
#     'prices': [{'id': '3',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 35000,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-04-20T20:54:30Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 1,
#    'sold_quantity': 500,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2041-04-01T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-615351672-alimento-comida-gato-gatsy-pescado-arroz-espinaca-3000-gr-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_747561-MCO45470967929_042021-I.jpg',
#    'thumbnail_id': '747561-MCO45470967929_042021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 36,
#     'amount': 972.22,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-DC',
#     'state_name': 'Bogotá D.C.',
#     'city_id': 'TUNPQ1NVQjUzNzQ4',
#     'city_name': 'Suba'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me2',
#     'tags': [],
#     'logistic_type': 'cross_docking',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-DC', 'name': 'Bogotá D.C.'},
#     'city': {'id': 'TUNPQ1NVQjUzNzQ4', 'name': 'Suba'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '5906197',
#      'source': 3045741222775799,
#      'value_name': 'Gatsy',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 3045741222775799,
#        'id': '5906197',
#        'name': 'Gatsy'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'id': 'ITEM_CONDITION',
#      'value_struct': None,
#      'value_name': 'Nuevo',
#      'values': [{'source': 3045741222775799,
#        'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None}],
#      'source': 3045741222775799,
#      'name': 'Condición del ítem',
#      'value_id': '2230284'}],
#    'original_price': None,
#    'category_id': 'MCO1087',
#    'official_store_id': None,
#    'domain_id': 'MCO-CATS_AND_DOGS_FOODS',
#    'catalog_product_id': None,
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible'],
#    'order_backend': 5,
#    'use_thumbnail_id': True},
#   {'id': 'MCO565209303',
#    'site_id': 'MCO',
#    'title': 'Cama Mediana Doble Faz Para Mascota',
#    'seller': {'id': 364199796,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 35900,
#    'prices': {'id': 'MCO565209303',
#     'prices': [{'id': '1',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 35900,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-05-12T02:31:53Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 100,
#    'sold_quantity': 500,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2040-05-30T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-565209303-cama-mediana-doble-faz-para-mascota-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_950246-MCO43765526528_102020-O.jpg',
#    'thumbnail_id': '950246-MCO43765526528_102020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 36,
#     'amount': 997.22,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-DC',
#     'state_name': 'Bogotá D.C.',
#     'city_id': 'TUNPQ0VORzkzMTUz',
#     'city_name': 'Engativá'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'logistic_type': 'xd_drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-DC', 'name': 'Bogotá D.C.'},
#     'city': {'id': 'TUNPQ0VORzkzMTUz', 'name': 'Engativá'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_name': 'Hally Pets',
#      'values': [{'struct': None,
#        'source': 6808261514773724,
#        'id': None,
#        'name': 'Hally Pets'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'id': 'BRAND',
#      'value_id': None,
#      'value_struct': None,
#      'source': 6808261514773724},
#     {'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'values': [{'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724,
#        'id': '2230284'}],
#      'source': 6808261514773724,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros'},
#     {'value_struct': None,
#      'attribute_group_name': 'Otros',
#      'id': 'MODEL',
#      'value_id': None,
#      'values': [{'id': None,
#        'name': 'Doble Faz',
#        'struct': None,
#        'source': 6808261514773724}],
#      'attribute_group_id': 'OTHERS',
#      'source': 6808261514773724,
#      'name': 'Modelo',
#      'value_name': 'Doble Faz'}],
#    'original_price': None,
#    'category_id': 'MCO155512',
#    'official_store_id': None,
#    'domain_id': 'MCO-DOG_BEDS',
#    'catalog_product_id': None,
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate'],
#    'order_backend': 6,
#    'use_thumbnail_id': False},
#   {'id': 'MCO552823965',
#    'site_id': 'MCO',
#    'title': 'Guante Quita Pelo Masajeador Silicona Perros Gatos Mascotas',
#    'seller': {'id': 347054769,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 6900,
#    'prices': {'id': 'MCO552823965',
#     'prices': [{'id': '3',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 6900,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-04-20T20:00:09Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 1,
#    'sold_quantity': 500,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-02-08T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-552823965-guante-quita-pelo-masajeador-silicona-perros-gatos-mascotas-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_878497-MCO40762199741_022020-O.jpg',
#    'thumbnail_id': '878497-MCO40762199741_022020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 575,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-DC',
#     'state_name': 'Bogotá D.C.',
#     'city_id': 'TUNPQ01BUjU5NzU1',
#     'city_name': 'Martires'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'logistic_type': 'cross_docking',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-DC', 'name': 'Bogotá D.C.'},
#     'city': {'id': 'TUNPQ01BUjU5NzU1', 'name': 'Martires'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 3376461333454861,
#      'name': 'Marca',
#      'value_id': '7447950',
#      'value_struct': None,
#      'values': [{'name': 'True Touch',
#        'struct': None,
#        'source': 3376461333454861,
#        'id': '7447950'}],
#      'id': 'BRAND',
#      'value_name': 'True Touch'},
#     {'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6808261514773724}],
#      'attribute_group_id': 'OTHERS',
#      'source': 6808261514773724,
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'attribute_group_name': 'Otros',
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Nuevo'},
#     {'value_struct': None,
#      'values': [{'struct': None,
#        'source': 3376461333454861,
#        'id': '6116013',
#        'name': 'Guante'}],
#      'value_id': '6116013',
#      'name': 'Modelo',
#      'value_name': 'Guante',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 3376461333454861,
#      'id': 'MODEL'},
#     {'source': 3376461333454861,
#      'id': 'RECOMMENDED_COAT_LENGTH',
#      'name': 'Largo del pelaje recomendado',
#      'value_id': '4260564',
#      'value_name': 'Largo',
#      'attribute_group_id': 'OTHERS',
#      'value_struct': None,
#      'values': [{'id': '4260564',
#        'name': 'Largo',
#        'struct': None,
#        'source': 3376461333454861}],
#      'attribute_group_name': 'Otros'}],
#    'differential_pricing': {'id': 33602181},
#    'original_price': None,
#    'category_id': 'MCO155535',
#    'official_store_id': None,
#    'domain_id': 'MCO-PET_BRUSHES',
#    'catalog_product_id': 'MCO14962309',
#    'tags': ['good_quality_thumbnail',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate'],
#    'order_backend': 7,
#    'use_thumbnail_id': False},
#   {'id': 'MCO598171624',
#    'site_id': 'MCO',
#    'title': 'Pechera Chaleco Arnés Para Mascota  Perro Gato Raza Pequeña ',
#    'seller': {'id': 78146695,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 23900,
#    'prices': {'id': 'MCO598171624',
#     'prices': [{'id': '2',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 23900,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-02-19T18:07:53Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 200,
#    'sold_quantity': 250,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-12-06T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-598171624-pechera-chaleco-arnes-para-mascota-perro-gato-raza-pequena-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_923898-MCO44949015673_022021-O.jpg',
#    'thumbnail_id': '923898-MCO44949015673_022021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 1991.67,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-ANT',
#     'state_name': 'Antioquia',
#     'city_id': 'TUNPQ01FRGRjNjc4',
#     'city_name': 'Medellín'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me2',
#     'tags': [],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-ANT', 'name': 'Antioquia'},
#     'city': {'id': 'TUNPQ01FRGRjNjc4', 'name': 'Medellín'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Condición del ítem',
#      'attribute_group_id': 'OTHERS',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 3045741222775799}],
#      'attribute_group_name': 'Otros',
#      'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_name': 'Nuevo'}],
#    'differential_pricing': {'id': 33602181},
#    'original_price': None,
#    'category_id': 'MCO370607',
#    'official_store_id': None,
#    'domain_id': 'MCO-DOG_HARNESSES',
#    'catalog_product_id': None,
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate'],
#    'order_backend': 8,
#    'use_thumbnail_id': False},
#   {'id': 'MCO474818949',
#    'site_id': 'MCO',
#    'title': 'Cachorros  Golden Retriever Cali Medellin Bogota',
#    'seller': {'id': 286610392,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 1980000,
#    'prices': {'id': 'MCO474818949',
#     'prices': [{'id': '1',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 1980000,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-01-17T21:23:47Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 1,
#    'sold_quantity': 3,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2040-01-28T14:59:42.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-474818949-cachorros-golden-retriever-cali-medellin-bogota-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_937599-MCO27610185417_062018-O.jpg',
#    'thumbnail_id': '937599-MCO27610185417_062018',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 36,
#     'amount': 55000,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-VAC',
#     'state_name': 'Valle Del Cauca',
#     'city_id': 'TUNPQ0NBTDYyZDA0',
#     'city_name': 'Cali'},
#    'shipping': {'free_shipping': False,
#     'mode': 'custom',
#     'tags': [],
#     'logistic_type': 'custom',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-VAC', 'name': 'Valle Del Cauca'},
#     'city': {'id': 'TUNPQ0NBTDYyZDA0', 'name': 'Cali'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'COAT_LENGTH',
#      'name': 'Largo del pelaje',
#      'value_struct': None,
#      'values': [{'source': 4709228965570453,
#        'id': '2307589',
#        'name': 'Largo',
#        'struct': None}],
#      'value_id': '2307589',
#      'value_name': 'Largo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 4709228965570453},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_name': 'Nuevo',
#      'source': 1572,
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1572}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros'}],
#    'original_price': None,
#    'category_id': 'MCO1073',
#    'official_store_id': None,
#    'domain_id': 'MCO-PUREBRED_DOGS',
#    'catalog_product_id': 'MCO6516524',
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment'],
#    'order_backend': 9,
#    'use_thumbnail_id': False},
#   {'id': 'MCO581999806',
#    'site_id': 'MCO',
#    'title': 'Cachorros Pastor Alemán Pelo Largo',
#    'seller': {'id': 296169084,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 1200000,
#    'prices': {'id': 'MCO581999806',
#     'prices': [{'id': '2',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 1200000,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-03-29T15:42:34Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 1,
#    'sold_quantity': 3,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-09-05T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-581999806-cachorros-pastor-aleman-pelo-largo-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_894317-MCO43431136193_092020-O.jpg',
#    'thumbnail_id': '894317-MCO43431136193_092020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 100000,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-DC',
#     'state_name': 'Bogotá D.C.',
#     'city_id': 'TUNPQ0JPUzQwMzcw',
#     'city_name': 'Bosa'},
#    'shipping': {'free_shipping': False,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': 'not_specified',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-DC', 'name': 'Bogotá D.C.'},
#     'city': {'id': 'TUNPQ0JPUzQwMzcw', 'name': 'Bosa'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_name': 'Otros',
#      'name': 'Largo del pelaje',
#      'value_name': 'Largo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'id': 'COAT_LENGTH',
#      'value_id': '2307589',
#      'values': [{'id': '2307589',
#        'name': 'Largo',
#        'struct': None,
#        'source': 4709228965570453}],
#      'source': 4709228965570453},
#     {'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'value_struct': None,
#      'source': 1505,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'attribute_group_name': 'Otros',
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1505}],
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33602181},
#    'original_price': None,
#    'category_id': 'MCO1073',
#    'official_store_id': None,
#    'domain_id': 'MCO-PUREBRED_DOGS',
#    'catalog_product_id': 'MCO6453598',
#    'tags': ['good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'good_quality_picture',
#     'immediate_payment'],
#    'order_backend': 10,
#    'use_thumbnail_id': False},
#   {'id': 'MCO463185590',
#    'site_id': 'MCO',
#    'title': 'Bulldog Frances Pereira Barranquilla Medellin Cali Bogota',
#    'seller': {'id': 102195773,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 2600000,
#    'prices': {'id': 'MCO463185590',
#     'prices': [{'id': '33ceb3e7-f757-416d-9c21-57752d025220',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 2600000,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2020-10-05T17:58:06Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 1,
#    'sold_quantity': 4,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2039-12-25T21:06:45.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-463185590-bulldog-frances-pereira-barranquilla-medellin-cali-bogota-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_706119-MCO44051522312_112020-O.jpg',
#    'thumbnail_id': '706119-MCO44051522312_112020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 36,
#     'amount': 72222.22,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-ANT',
#     'state_name': 'Antioquia',
#     'city_id': 'TUNPQ01FRGRjNjc4',
#     'city_name': 'Medellín'},
#    'shipping': {'free_shipping': False,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': 'not_specified',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-ANT', 'name': 'Antioquia'},
#     'city': {'id': 'TUNPQ01FRGRjNjc4', 'name': 'Medellín'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'COAT_LENGTH',
#      'value_id': '2307588',
#      'value_name': 'Corto',
#      'attribute_group_name': 'Otros',
#      'source': 7092,
#      'name': 'Largo del pelaje',
#      'value_struct': None,
#      'values': [{'id': '2307588',
#        'name': 'Corto',
#        'struct': None,
#        'source': 7092}],
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'ITEM_CONDITION',
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 1,
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'value_struct': None}],
#    'original_price': None,
#    'category_id': 'MCO1073',
#    'official_store_id': None,
#    'domain_id': 'MCO-PUREBRED_DOGS',
#    'catalog_product_id': 'MCO6417221',
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment'],
#    'order_backend': 11,
#    'use_thumbnail_id': False},
#   {'id': 'MCO474734533',
#    'site_id': 'MCO',
#    'title': 'Vendo Perros De Raza Bulldog Francés De Certificación Medica',
#    'seller': {'id': 102195773,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 2500000,
#    'prices': {'id': 'MCO474734533',
#     'prices': [{'id': 'ad0026b8-ddeb-4442-8a52-9279b8b7282a',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 2500000,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2020-09-02T17:10:20Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 1,
#    'sold_quantity': 1,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-03-11T01:54:37.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-474734533-vendo-perros-de-raza-bulldog-frances-de-certificacion-medica-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_879307-MCO27605072217_062018-O.jpg',
#    'thumbnail_id': '879307-MCO27605072217_062018',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 208333.33,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-ANT',
#     'state_name': 'Antioquia',
#     'city_id': 'TUNPQ01FRGRjNjc4',
#     'city_name': 'Medellín'},
#    'shipping': {'free_shipping': False,
#     'mode': 'custom',
#     'tags': [],
#     'logistic_type': 'custom',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-ANT', 'name': 'Antioquia'},
#     'city': {'id': 'TUNPQ01FRGRjNjc4', 'name': 'Medellín'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_name': 'Corto',
#      'value_struct': None,
#      'values': [{'id': '2307588',
#        'name': 'Corto',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_id': 'OTHERS',
#      'source': 4709228965570453,
#      'id': 'COAT_LENGTH',
#      'name': 'Largo del pelaje',
#      'value_id': '2307588',
#      'attribute_group_name': 'Otros'},
#     {'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'source': 1572,
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 1572}],
#      'attribute_group_name': 'Otros',
#      'id': 'ITEM_CONDITION'}],
#    'differential_pricing': {'id': 33602181},
#    'original_price': None,
#    'category_id': 'MCO1073',
#    'official_store_id': None,
#    'domain_id': 'MCO-PUREBRED_DOGS',
#    'catalog_product_id': 'MCO6452804',
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment'],
#    'order_backend': 12,
#    'use_thumbnail_id': False},
#   {'id': 'MCO555644895',
#    'site_id': 'MCO',
#    'title': 'Vendo Cachorros Pomerania Lulu Mini Blancos Café Caramelo ',
#    'seller': {'id': 528732202,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 3000000,
#    'prices': {'id': 'MCO555644895',
#     'prices': [{'id': '1',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 3000000,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-03-17T01:00:37Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 1,
#    'sold_quantity': 1,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-03-03T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-555644895-vendo-cachorros-pomerania-lulu-mini-blancos-cafe-caramelo-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_702667-MCO41048195982_032020-O.jpg',
#    'thumbnail_id': '702667-MCO41048195982_032020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 250000,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-ANT',
#     'state_name': 'Antioquia',
#     'city_id': 'TUNPQ01FRGRjNjc4',
#     'city_name': 'Medellín'},
#    'shipping': {'free_shipping': False,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': 'not_specified',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-ANT', 'name': 'Antioquia'},
#     'city': {'id': 'TUNPQ01FRGRjNjc4', 'name': 'Medellín'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_name': 'Largo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'id': 'COAT_LENGTH',
#      'value_id': '2307589',
#      'values': [{'id': '2307589',
#        'name': 'Largo',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_name': 'Otros',
#      'source': 4709228965570453,
#      'name': 'Largo del pelaje'},
#     {'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 7092,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 7092}]}],
#    'differential_pricing': {'id': 33602181},
#    'original_price': None,
#    'category_id': 'MCO1073',
#    'official_store_id': None,
#    'domain_id': 'MCO-PUREBRED_DOGS',
#    'catalog_product_id': 'MCO6504342',
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment'],
#    'order_backend': 13,
#    'use_thumbnail_id': False},
#   {'id': 'MCO575199063',
#    'site_id': 'MCO',
#    'title': 'Vendo Cachorros Lobo Miniatura Pomsky Siberiano Mini Pomskie',
#    'seller': {'id': 528732202,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 7500000,
#    'prices': {'id': 'MCO575199063',
#     'prices': [{'id': 'b72935e2-7163-4ef9-b38b-355828c3782b',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 7500000,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2020-09-28T01:42:34Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-07-31T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-575199063-vendo-cachorros-lobo-miniatura-pomsky-siberiano-mini-pomskie-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_934872-MCO43046381322_082020-I.jpg',
#    'thumbnail_id': '934872-MCO43046381322_082020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 625000,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-ANT',
#     'state_name': 'Antioquia',
#     'city_id': 'TUNPQ01FRGRjNjc4',
#     'city_name': 'Medellín'},
#    'shipping': {'free_shipping': False,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': 'not_specified',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-ANT', 'name': 'Antioquia'},
#     'city': {'id': 'TUNPQ01FRGRjNjc4', 'name': 'Medellín'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Largo del pelaje',
#      'value_struct': None,
#      'values': [{'name': 'Corto',
#        'struct': None,
#        'source': 4709228965570453,
#        'id': '2307588'}],
#      'attribute_group_name': 'Otros',
#      'source': 4709228965570453,
#      'id': 'COAT_LENGTH',
#      'value_id': '2307588',
#      'value_name': 'Corto',
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 7092,
#      'name': 'Condición del ítem',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 7092}]}],
#    'differential_pricing': {'id': 33602181},
#    'original_price': None,
#    'category_id': 'MCO1073',
#    'official_store_id': None,
# ...
#    'prices': {'id': 'MCO563431160',
#     'prices': [{'id': '5',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 145900,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-05-23T20:46:14Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 1,
#    'sold_quantity': 1,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2040-05-17T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-563431160-pinscher-miniaturablack-original-perro-figura-decorativa-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_849409-MCO41909872893_052020-I.jpg',
#    'thumbnail_id': '849409-MCO41909872893_052020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 36,
#     'amount': 4052.78,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-DC',
#     'state_name': 'Bogotá D.C.',
#     'city_id': 'TUNPQ0VORzkzMTUz',
#     'city_name': 'Engativá'},
#    'shipping': {'free_shipping': False,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': 'not_specified',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-DC', 'name': 'Bogotá D.C.'},
#     'city': {'id': 'TUNPQ0VORzkzMTUz', 'name': 'Engativá'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'attribute_group_id': 'OTHERS',
#      'source': 4709228965570453,
#      'name': 'Largo del pelaje',
#      'value_id': '2307588',
#      'value_name': 'Corto',
#      'attribute_group_name': 'Otros',
#      'id': 'COAT_LENGTH',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 4709228965570453,
#        'id': '2307588',
#        'name': 'Corto'}]},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 1,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_struct': None,
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'values': [{'source': 1,
#        'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None}]}],
#    'original_price': None,
#    'category_id': 'MCO1073',
#    'official_store_id': None,
#    'domain_id': 'MCO-PUREBRED_DOGS',
#    'catalog_product_id': 'MCO6419764',
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment'],
#    'order_backend': 48,
#    'use_thumbnail_id': True},
#   {'id': 'MCO601793991',
#    'site_id': 'MCO',
#    'title': 'Guante Peinar Acariciar Mascotas + Cepillo Quita Motas Pelos',
#    'seller': {'id': 208307959,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 29900,
#    'prices': {'id': 'MCO601793991',
#     'prices': [{'id': '1',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 29900,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-01-14T20:03:12Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 500,
#    'sold_quantity': 200,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2041-01-09T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-601793991-guante-peinar-acariciar-mascotas-cepillo-quita-motas-pelos-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_682595-MCO44585341410_012021-O.jpg',
#    'thumbnail_id': '682595-MCO44585341410_012021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 36,
#     'amount': 830.56,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-DC',
#     'state_name': 'Bogotá D.C.',
#     'city_id': 'TUNPQ01BUjU5NzU1',
#     'city_name': 'Martires'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me2',
#     'tags': ['self_service_in'],
#     'logistic_type': 'cross_docking',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-DC', 'name': 'Bogotá D.C.'},
#     'city': {'id': 'TUNPQ01BUjU5NzU1', 'name': 'Martires'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'value_id': '7447950',
#      'value_struct': None,
#      'values': [{'id': '7447950',
#        'name': 'True Touch',
#        'struct': None,
#        'source': 2860837171021627}],
#      'name': 'Marca',
#      'value_name': 'True Touch',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'source': 2860837171021627},
#     {'value_struct': None,
#      'attribute_group_name': 'Otros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'attribute_group_id': 'OTHERS',
#      'source': 2860837171021627},
#     {'name': 'Modelo',
#      'value_id': '6116013',
#      'value_name': 'Guante',
#      'value_struct': None,
#      'attribute_group_name': 'Otros',
#      'source': 2860837171021627,
#      'id': 'MODEL',
#      'attribute_group_id': 'OTHERS',
#      'values': [{'id': '6116013',
#        'name': 'Guante',
#        'struct': None,
#        'source': 2860837171021627}]},
#     {'id': 'RECOMMENDED_COAT_LENGTH',
#      'value_id': '-1',
#      'values': [{'struct': None,
#        'source': 2860837171021627,
#        'id': '-1',
#        'name': None}],
#      'attribute_group_id': 'OTHERS',
#      'source': 2860837171021627,
#      'name': 'Largo del pelaje recomendado',
#      'value_name': None,
#      'value_struct': None,
#      'attribute_group_name': 'Otros'}],
#    'original_price': None,
#    'category_id': 'MCO155535',
#    'official_store_id': None,
#    'domain_id': 'MCO-PET_BRUSHES',
#    'catalog_product_id': 'MCO14962309',
#    'tags': ['good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible',
#     'best_seller_candidate'],
#    'order_backend': 49,
#    'use_thumbnail_id': False},
#   {'id': 'MCO592331594',
#    'site_id': 'MCO',
#    'title': 'Vendo Cachorros Pastor Alemán Pelo Largo Pastores Cachorro ',
#    'seller': {'id': 528732202,
#     'permalink': None,
#     'registration_date': None,
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': None},
#    'price': 3500000,
#    'prices': {'id': 'MCO592331594',
#     'prices': [{'id': '1',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 3500000,
#       'regular_amount': None,
#       'currency_id': 'COP',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-03-17T03:10:35Z'}],
#     'presentation': {'display_currency': 'COP'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'COP',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-10-24T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://articulo.mercadolibre.com.co/MCO-592331594-vendo-cachorros-pastor-aleman-pelo-largo-pastores-cachorro-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_638656-MCO40877687967_022020-O.jpg',
#    'thumbnail_id': '638656-MCO40877687967_022020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 291666.67,
#     'rate': 0,
#     'currency_id': 'COP'},
#    'address': {'state_id': 'CO-ANT',
#     'state_name': 'Antioquia',
#     'city_id': 'TUNPQ01FRGRjNjc4',
#     'city_name': 'Medellín'},
#    'shipping': {'free_shipping': False,
#     'mode': 'not_specified',
#     'tags': [],
#     'logistic_type': 'not_specified',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'CO', 'name': 'Colombia'},
#     'state': {'id': 'CO-ANT', 'name': 'Antioquia'},
#     'city': {'id': 'TUNPQ01FRGRjNjc4', 'name': 'Medellín'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Largo del pelaje',
#      'value_struct': None,
#      'values': [{'id': '2307589',
#        'name': 'Largo',
#        'struct': None,
#        'source': 4709228965570453}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'id': 'COAT_LENGTH',
#      'value_id': '2307589',
#      'value_name': 'Largo',
#      'source': 4709228965570453},
#     {'attribute_group_id': 'OTHERS',
#      'source': 7092,
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'values': [{'source': 7092,
#        'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None}],
#      'attribute_group_name': 'Otros',
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Nuevo',
#      'value_struct': None}],
#    'differential_pricing': {'id': 33602181},
#    'original_price': None,
#    'category_id': 'MCO1073',
#    'official_store_id': None,
#    'domain_id': 'MCO-PUREBRED_DOGS',
#    'catalog_product_id': 'MCO6453598',
#    'tags': ['good_quality_picture',
#     'good_quality_thumbnail',
#     'immediate_payment'],
#    'order_backend': 50,
#    'use_thumbnail_id': False}],
#  'secondary_results': [],
#  'related_results': [],
#  'sort': {'id': 'relevance', 'name': 'Más relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor precio'},
#   {'id': 'price_desc', 'name': 'Mayor precio'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorías',
#    'type': 'text',
#    'values': [{'id': 'MCO1071',
#      'name': 'Animales y Mascotas',
#      'path_from_root': [{'id': 'MCO1071', 'name': 'Animales y Mascotas'}]}]}],
#  'available_filters': [{'id': 'category',
#    'name': 'Categorías',
#    'type': 'text',
#    'values': [{'id': 'MCO1072', 'name': 'Perros', 'results': 540247},
#     {'id': 'MCO1081', 'name': 'Gatos', 'results': 131501},
#     {'id': 'MCO1091', 'name': 'Peces', 'results': 62097},
#     {'id': 'MCO1100', 'name': 'Aves', 'results': 30153},
#     {'id': 'MCO6142', 'name': 'Caballos', 'results': 11721},
#     {'id': 'MCO1105', 'name': 'Roedores', 'results': 5859},
#     {'id': 'MCO270897', 'name': 'Reptiles y Anfibios', 'results': 2624},
#     {'id': 'MCO436892', 'name': 'Conejos', 'results': 880},
#     {'id': 'MCO429311', 'name': 'Insectos', 'results': 80},
#     {'id': 'MCO6152', 'name': 'Otros', 'results': 13632}]},
#   {'id': 'official_store',
#    'name': 'Tiendas oficiales',
#    'type': 'text',
#    'values': [{'id': 'all',
#      'name': 'Todas las tiendas oficiales',
#      'results': 7351},
#     {'id': '589', 'name': 'Puppis', 'results': 1653},
#     {'id': '664', 'name': 'Mascotas Bichos', 'results': 1217},
#     {'id': '1067', 'name': 'Wof Wof', 'results': 9}]},
#   {'id': 'discount',
#    'name': 'Descuentos',
#    'type': 'range',
#    'values': [{'id': '5-100', 'name': 'Desde 5% OFF', 'results': 2939},
#     {'id': '10-100', 'name': 'Desde 10% OFF', 'results': 2481},
#     {'id': '15-100', 'name': 'Desde 15% OFF', 'results': 1305},
#     {'id': '20-100', 'name': 'Desde 20% OFF', 'results': 473},
#     {'id': '25-100', 'name': 'Desde 25% OFF', 'results': 161},
#     {'id': '30-100', 'name': 'Desde 30% OFF', 'results': 153}]},
#   {'id': 'state',
#    'name': 'Ubicación',
#    'type': 'text',
#    'values': [{'id': 'CO-DC', 'name': 'Bogotá D.C.', 'results': 375717},
#     {'id': 'CO-CES', 'name': 'Cesar', 'results': 102161},
#     {'id': 'CO-ANT', 'name': 'Antioquia', 'results': 80806},
#     {'id': 'CO-MET', 'name': 'Meta', 'results': 44160},
#     {'id': 'CO-SAN', 'name': 'Santander', 'results': 29170},
#     {'id': 'CO-CUN', 'name': 'Cundinamarca', 'results': 20284},
#     {'id': 'CO-BOL', 'name': 'Bolivar', 'results': 19968},
#     {'id': 'CO-ATL', 'name': 'Atlantico', 'results': 18936},
#     {'id': 'CO-VAC', 'name': 'Valle Del Cauca', 'results': 17182},
#     {'id': 'CO-NSA', 'name': 'Norte De Santander', 'results': 4864},
#     {'id': 'CO-QUI', 'name': 'Quindio', 'results': 4112},
#     {'id': 'CO-CAL', 'name': 'Caldas', 'results': 2922},
#     {'id': 'CO-RIS', 'name': 'Risaralda', 'results': 1496},
#     {'id': 'CO-BOY', 'name': 'Boyaca', 'results': 1305},
#     {'id': 'CO-TOL', 'name': 'Tolima', 'results': 961},
#     {'id': 'CO-MAG', 'name': 'Magdalena', 'results': 296},
#     {'id': 'CO-NAR', 'name': 'Nariño', 'results': 280},
#     {'id': 'CO-CHO', 'name': 'Choco', 'results': 192},
#     {'id': 'CO-HUI', 'name': 'Huila', 'results': 176},
#     {'id': 'CO-ARA', 'name': 'Arauca', 'results': 136},
#     {'id': 'CO-CAU', 'name': 'Cauca', 'results': 104},
#     {'id': 'CO-COR', 'name': 'Córdoba', 'results': 96},
#     {'id': 'CO-LAG', 'name': 'Guajira', 'results': 80},
#     {'id': 'CO-CAS', 'name': 'Casanare', 'results': 48},
#     {'id': 'CO-SUC', 'name': 'Sucre', 'results': 48},
#     {'id': 'CO-CAQ', 'name': 'Caqueta', 'results': 32},
#     {'id': 'CO-SAP', 'name': 'San Andres y Providencia', 'results': 8}]},
#   {'id': 'price',
#    'name': 'Precio',
#    'type': 'range',
#    'values': [{'id': '*-100000.0',
#      'name': 'Hasta $100.000',
#      'results': 199342},
#     {'id': '100000.0-150000.0',
#      'name': '$100.000 a $150.000',
#      'results': 241235},
#     {'id': '150000.0-*', 'name': 'Más de $150.000', 'results': 332507}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con MercadoPago', 'results': 773084}]},
#   {'id': 'installments',
#    'name': 'Pago',
#    'type': 'text',
#    'values': [{'id': 'yes', 'name': 'En cuotas', 'results': 772979},
#     {'id': 'no_interest', 'name': 'Cuotas sin interés', 'results': 278684}]},
#   {'id': 'shipping',
#    'name': 'Envío',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envíos',
#      'results': 702230},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 251}]},
#   {'id': 'power_seller',
#    'name': 'Filtro por calidad de vendedores',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Mejores vendedores', 'results': 423958}]},
#   {'id': 'since',
#    'name': 'Filtro por fecha de comienzo',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Publicados hoy', 'results': 2304}]},
#   {'id': 'until',
#    'name': 'Filtro por fecha de finalización',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Finalizan hoy', 'results': 48}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicaciones con video',
#    'type': 'boolean',
#    'values': [{'id': 'yes',
#      'name': 'Publicaciones con video',
#      'results': 11240}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicaciones con imágenes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con fotos', 'results': 772732}]},
#   {'id': 'price_campaign_id',
#    'name': 'Campaña',
#    'type': 'number',
#    'values': [{'id': 'MCO1815', 'name': 'MCO1815', 'results': 1}]},
#   {'id': 'shipping_cost',
#    'name': 'Costo de envío',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 629033}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230284', 'name': 'Nuevo', 'results': 675822},
#     {'id': '2230581', 'name': 'Usado', 'results': 938}]},
#   {'id': 'SHIPPING_ORIGIN',
#    'name': 'Tipo de compra',
#    'type': 'STRING',
#    'values': [{'id': '10215068', 'name': 'Local', 'results': 635495},
#     {'id': '10215069', 'name': 'Internacional', 'results': 41566}]}]}

# %% [markdown]
# Ahora se concatena el fragmento de api "https://api.mercadolibre.com/sites/MCO/search?" con el id de cada una de las categorías guardadas en el diccionario diccat, recorriendo este diccionario se hace el llamado de la api de cada categoía (tomando las 50 primeras hojas) y los resultados se guardan en el diccionario d_product.

# %%
offset= [0,50,100,150,200,250,300,400,450,500,550,600,650,700,750]
d_product=[]
for cat in tqdm(diccat):
    for i in offset:
        
        api = f'https://api.mercadolibre.com/sites/MCO/search?'
        cat_id = cat['id']
        catml= f'category={cat_id}&offset={i}'
        r =requests.get(f'{api}{catml}')
        d_product.append(r.json())
# Out:
# 100%|██████████| 32/32 [11:49<00:00, 22.17s/it]

# %% [markdown]
# Hasta aca hemos guardado en el diccionario d_product toda la información de los productos de cada categoría (los productos que aparecen en las primeras 50 hojas), ahora se hará el llamado de la información relacionada con el vendedor, teniendo en cuenta que la api que contiene la información de los vendedores es "https://api.mercadolibre.com/users/id_seller", donde id_seller sera reemplazado por el número de id del vendedor, el cual lo podemos encontrar en el diccionario d_product.

# %% [markdown]
# de d_product traemos el id del vendedor para poder relacionarlo en la api de los usuarios, posteriormente se hace el llamado de un solo usuario para que podamos visualizar la información disponible del vendedor:

# %%
id_seller=d_product[0]["results"][0]["seller"]["id"]
callsell=f'https://api.mercadolibre.com/users/{id_seller}'

# %%
s =requests.get(callsell)
s.json()
# Out:
# {'id': 147458773,
#  'nickname': 'GMCOMUNICACIONESY ELECTRONICA',
#  'registration_date': '2013-10-14T13:45:44.000-04:00',
#  'country_id': 'CO',
#  'address': {'city': 'Puente Aranda', 'state': 'CO-DC'},
#  'user_type': 'normal',
#  'tags': ['normal', 'eshop', 'mshops'],
#  'logo': None,
#  'points': 6633,
#  'site_id': 'MCO',
#  'permalink': 'http://perfil.mercadolibre.com.co/GMCOMUNICACIONESY+ELECTRONICA',
#  'seller_reputation': {'level_id': '5_green',
#   'power_seller_status': 'platinum',
#   'transactions': {'canceled': 875,
#    'completed': 19404,
#    'period': 'historic',
#    'ratings': {'negative': 0.03, 'neutral': 0.03, 'positive': 0.94},
#    'total': 20279}},
#  'buyer_reputation': {'tags': []},
#  'status': {'site_status': 'active'}}

# %% [markdown]
# Conociendo que información podemos disponer del producto y del vendedor, se hará un recorrido con metodo for en cada categoría guardada en dic_product, y luego se recorrerá cada uno de los nombres y los valores del objeto results de las categorías, para finalmente guardar toda la información en un DataFrame:

# %%
object_names = ['id', 'site_id', 'title', 'price', 'sale_price',
             'currency_id', 'available_quantity', 'sold_quantity', 'buying_mode',
             'listing_type_id', 'stop_time', 'condition', 'permalink', 'thumbnail', 
             'thumbnail_id', 'accepts_mercadopago', 'original_price', 
             'category_id', 'official_store_id', 'domain_id', 'catalog_product_id',
              'use_thumbnail_id'] # nombres a traer del objeto results de cada una de las api de categorías.
dataset_productos = pd.DataFrame()
for i in tqdm(d_product):
    for result in i["results"]:
        try: #se declara try pues se intentó sin este y el for se detenia por el error de ejecución: "results",
            # por tanto se manejara este error de ejecución como una excepción
    
            
            dataset = {'object_'+name: result[name] for name in object_names}#guardamos en "dataset" los nombres (y sus valores) 
            dataset['General_category_id'] = i['filters'][0]['values'][0]['id']
            dataset['General_category_name'] = i['filters'][0]['values'][0]['name']


            dataset['free_ship'] = result['shipping']['free_shipping']# creamos nuevas columnas en dataset para guardar
            dataset['ship_mode'] = result['shipping']['mode']         # la información de ship que esta dentro de una jerarqía
            dataset['ship_logistic_type'] = result['shipping']['logistic_type']
            dataset['ship_storepickup'] = result['shipping']['store_pick_up']



            id_seller=result["seller"]["id"] # de cada objeto results de cada categoría traemos el id del vendedor

            callsell=f'https://api.mercadolibre.com/users/{id_seller}' 
            s =requests.get(callsell) # con cada id se hace el llamado de la api que contiene la información del vendedor
            sj=s.json()
            dataset["seller_level"] = sj["seller_reputation"] ["level_id"] # se crean nuevas columnas en dataset para guardar la información del vendedor
            dataset["seller_power_status"] = sj["seller_reputation"] ["power_seller_status"]
            dataset["sellertransactions_canceled"] = sj["seller_reputation"]["transactions"] ["canceled"]
            dataset["sellertransactions_completed"] = sj["seller_reputation"]["transactions"] ["completed"]
            dataset["sellertransactions_total"] = sj["seller_reputation"]["transactions"] ["total"]
            dataset["sellertransactions_period"] = sj["seller_reputation"]["transactions"] ["period"]
            dataset["sellerrating_negative"] = sj["seller_reputation"]["transactions"] ["ratings"]["negative"]
            dataset["sellerrating_neutral"] = sj["seller_reputation"]["transactions"] ["ratings"]["neutral"]
            dataset["sellerrating_positive"] = sj["seller_reputation"]["transactions"] ["ratings"]["positive"]
            item = pd.DataFrame(dataset, index=[0])
            dataset_productos= pd.concat([item, dataset_productos], axis=0) # se concatena la información de cada categoria
            
        except:
            print("error de ejecución")
# Out:
# 100%|██████████| 480/480 [2:02:04<00:00, 15.26s/it]

# %%
dataset_productos.shape
# Out:
# (23601, 37)

# %% [markdown]
# Puesto que llamar toda la información tardó cerca de 2 horas, se guradará el dataset en un csv, para trabajar en los siguientes puntos sobre este archivo:

# %%
ruta = "./files/dataset_productos.csv"
dataset_productos.to_csv(ruta,index=False)
